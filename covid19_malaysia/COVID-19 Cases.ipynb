# %% [markdown]
# # COVID-19 Cases in Malaysia

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Daily recorded COVID-19 cases at country level

# %%
url_cases1 = "https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_malaysia.csv"

# %%
df1 = pd.read_csv(url_cases1,parse_dates=["date"],usecols=['date','cases_new','cases_recovered','cases_active'])
df1.set_index('date',inplace=True)
df1
# Out:
#             cases_new  cases_recovered  cases_active
# date
# 2020-01-25          4                0             4
# 2020-01-26          0                0             4
# 2020-01-27          0                0             4
# 2020-01-28          0                0             4
# 2020-01-29          3                0             7
# ...               ...              ...           ...
# 2021-11-19       6355             5031         68534
# 2021-11-20       5859             4970         69411
# 2021-11-21       4854             5525         68729
# 2021-11-22       4885             5628         67986
# 2021-11-23       5594             4908         68625
#
# [669 rows x 3 columns]

# %%
plt.figure(figsize=(15, 8))
plt.grid()
plt.title("Daily Recorded COVID-19 Cases")
plt.xlabel("Time")
plt.ylabel("Number of cases")
plt.plot(df1)
plt.legend(['cases_new','cases_import','cases_recovered','cases_active'])

# %% [markdown]
# ## Daily recorded COVID-19 cases at state level

# %%
url_cases2 = "https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_state.csv"

# %%
df2 = pd.read_csv(url_cases2,parse_dates=["date"],usecols=['date','state','cases_new','cases_recovered','cases_active'])
df2.set_index('date',inplace=True)
df2.tail(20)
# Out:
#                         state  cases_new  cases_recovered  cases_active
# date
# 2021-11-22         Terengganu        202              166          2661
# 2021-11-22  W.P. Kuala Lumpur        208              175          4477
# 2021-11-22        W.P. Labuan         10               21           123
# 2021-11-22     W.P. Putrajaya         70               28           830
# 2021-11-23              Johor        569              318          7088
# 2021-11-23              Kedah        471              312          3270
# 2021-11-23           Kelantan        640              475          6423
# 2021-11-23             Melaka        112               85          1694
# 2021-11-23    Negeri Sembilan        139              134          2495
# 2021-11-23             Pahang        278              505          3927
# 2021-11-23              Perak        226              285          2370
# 2021-11-23             Perlis         31               33           325
# ...

# %%
plt.figure(figsize=(15, 8))
plt.grid()
plt.title("Daily Recorded COVID-19 Cases (By State)")
plt.xlabel("Time")
plt.ylabel("Number of cases")
plt.plot(df2.index,df2['cases_new','cases_recovered']) # Need to fix this
plt.legend(['cases_new','cases_import','cases_recovered','cases_active'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('cases_new', 'cases_recovered')
#
# ...
