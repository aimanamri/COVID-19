# %% [markdown]
# # COVID-19 Testing in Malaysia

# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %%
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/tests_malaysia.csv'

# %%
df = pd.read_csv(url,parse_dates=["date"])
df.set_index('date',inplace=True)
df
# Out:
#             rtk-ag    pcr
# date
# 2020-01-24       0      2
# 2020-01-25       0      5
# 2020-01-26       0     14
# 2020-01-27       0     24
# 2020-01-28       0     53
# ...            ...    ...
# 2021-11-17  105970  35193
# 2021-11-18   90805  32469
# 2021-11-19   82113  30566
# 2021-11-20   63460  27669
# 2021-11-21   69282  21779
#
# [668 rows x 2 columns]

# %%
plt.figure(figsize=(15, 8))
plt.fill_between(df.index,df['rtk-ag'], df['pcr'], color='k', alpha=.15)
plt.grid()
plt.plot(df)
plt.legend(['Difference','Antigen Rapid Test Kits (RTK-Ag)','Real-time Reverse Transcription Polymerase Chain Reaction (RT-PCR)'])
